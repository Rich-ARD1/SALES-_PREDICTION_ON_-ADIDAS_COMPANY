# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Rich\Desktop\Adidas US Sales Datasets.csv')

# %%
df = df. drop(labels=[0,1], axis = 0)

# %%
df.head()
# Out:
#     Unnamed: 0 Adidas Sales Database    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2     Retailer           Retailer ID  Invoice Date     Region      State
# 3  Foot Locker               1185732    01/01/2020  Northeast   New York
# 4  Foot Locker               1185732    02/01/2020  Northeast   New York
# 5  Foot Locker               1185732    03/01/2020  Northeast   New York
# 6  Foot Locker               1185732    04/01/2020  Northeast   New York
#
#   Unnamed: 5                 Unnamed: 6      Unnamed: 7  Unnamed: 8  \
# 2       City                    Product  Price per Unit  Units Sold
# 3   New York      Men's Street Footwear         $50.00        1,200
# 4   New York    Men's Athletic Footwear         $50.00        1,000
# 5   New York    Women's Street Footwear         $40.00        1,000
# 6   New York  Women's Athletic Footwear         $45.00          850
#
#     Unnamed: 9       Unnamed: 10       Unnamed: 11   Unnamed: 12
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.columns = df.iloc[0]

# %%
df = df.drop(labels=[0], axis=0)

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   01/01/2020  Northeast  New York  New York
# 2  Foot Locker     1185732   02/01/2020  Northeast  New York  New York
# 3  Foot Locker     1185732   03/01/2020  Northeast  New York  New York
# 4  Foot Locker     1185732   04/01/2020  Northeast  New York  New York
# 5  Foot Locker     1185732   05/01/2020  Northeast  New York  New York
#
# 0                    Product Price per Unit Units Sold Total Sales  \
# 1      Men's Street Footwear        $50.00       1,200   $600,000
# 2    Men's Athletic Footwear        $50.00       1,000   $500,000
# 3    Women's Street Footwear        $40.00       1,000   $400,000
# 4  Women's Athletic Footwear        $45.00         850   $382,500
# 5              Men's Apparel        $60.00         900   $540,000
#
# 0 Operating Profit Operating Margin Sales Method
# 1        $300,000               50%     In-store
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 1 to 9648
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
df['Price per Unit'] = df['Price per Unit'].str.replace('$', '').str.strip()
# Out:
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\2079624864.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price per Unit'] = df['Price per Unit'].str.replace('$', '').str.strip()

# %%
df['Units Sold'] = df['Units Sold'].str.replace(',', '')

# %%
df['Total Sales'] = df['Total Sales'].str.replace('$', '').str.strip()
# Out:
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\2220968791.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Total Sales'] = df['Total Sales'].str.replace('$', '').str.strip()

# %%
df['Operating Margin'] = df['Operating Margin'].str.replace('$', '').str.strip()
# Out:
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\2432723182.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Operating Margin'] = df['Operating Margin'].str.replace('$', '').str.strip()

# %%
df['Operating Margin'] = df['Operating Margin'].str.replace('%', '', regex=True)
df['Total Sales'] = df['Total Sales'].str.replace(',', '', regex=True)
df['Price per Unit'] = df['Price per Unit'].str.replace(',', '', regex=True)

# %%
df[['Price per Unit','Units Sold','Total Sales','Operating Margin']]= df[['Price per Unit','Units Sold','Total Sales','Operating Margin']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 1 to 9648
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   float64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 980.0+ KB

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   01/01/2020  Northeast  New York  New York
# 2  Foot Locker     1185732   02/01/2020  Northeast  New York  New York
# 3  Foot Locker     1185732   03/01/2020  Northeast  New York  New York
# 4  Foot Locker     1185732   04/01/2020  Northeast  New York  New York
# 5  Foot Locker     1185732   05/01/2020  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method
# 1        $300,000               50.0     In-store
# ...

# %%
df['Operating Profit'] = df['Operating Profit'].str.replace('$', '').str.strip()
df['Operating Profit'] = df['Operating Profit'].str.replace(',', '').str.strip()
# Out:
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\4221009802.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Operating Profit'] = df['Operating Profit'].str.replace('$', '').str.strip()

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   01/01/2020  Northeast  New York  New York
# 2  Foot Locker     1185732   02/01/2020  Northeast  New York  New York
# 3  Foot Locker     1185732   03/01/2020  Northeast  New York  New York
# 4  Foot Locker     1185732   04/01/2020  Northeast  New York  New York
# 5  Foot Locker     1185732   05/01/2020  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method
# 1           300000              50.0     In-store
# ...

# %%
df.describe()
# Out:
# 0      Price per Unit   Units Sold    Total Sales  Operating Margin
# count     9648.000000  9648.000000    9648.000000       9648.000000
# mean        45.216625   256.930037   93273.437500         42.299129
# std         14.705397   214.252030  141916.016727          9.719742
# min          7.000000     0.000000       0.000000         10.000000
# 25%         35.000000   106.000000    4254.500000         35.000000
# 50%         45.000000   176.000000    9576.000000         41.000000
# 75%         55.000000   350.000000  150000.000000         49.000000
# max        110.000000  1275.000000  825000.000000         80.000000

# %%
df['Year']=pd.to_datetime(df['Invoice Date']).dt.year
df['Month']=pd.to_datetime(df['Invoice Date']).dt.strftime('%B')
df['Invoice Date']=pd.to_datetime(df['Invoice Date']).dt.strftime('%Y-%m-%d')
# Out:
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\1092158175.py:1: UserWarning: Parsing '21/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Year']=pd.to_datetime(df['Invoice Date']).dt.year
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\1092158175.py:1: UserWarning: Parsing '22/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Year']=pd.to_datetime(df['Invoice Date']).dt.year
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\1092158175.py:1: UserWarning: Parsing '23/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Year']=pd.to_datetime(df['Invoice Date']).dt.year
# C:\Users\Rich\AppData\Local\Temp\ipykernel_8520\1092158175.py:1: UserWarning: Parsing '24/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
def func(x):
    if(x[0]=='M'):
        return 'Male'
    else:
        return 'Female'
    
df['Gender'] = df['Product'].apply(func)

df
# Out:
# 0        Retailer Retailer ID Invoice Date     Region          State  \
# 1     Foot Locker     1185732   2020-01-01  Northeast       New York
# 2     Foot Locker     1185732   2020-02-01  Northeast       New York
# 3     Foot Locker     1185732   2020-03-01  Northeast       New York
# 4     Foot Locker     1185732   2020-04-01  Northeast       New York
# 5     Foot Locker     1185732   2020-05-01  Northeast       New York
# ...           ...         ...          ...        ...            ...
# 9644  Foot Locker     1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker     1185732   2021-01-24  Northeast  New Hampshire
# 9646  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
# 9648  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
#
# 0           City                    Product  Price per Unit  Units Sold  \
# ...

# %%
df_filled = df[df['Year'] == 2020]
top_products_20 = df_filled[['Product','Total Sales']] . groupby('Product'). sum()
top_products_20 = top_products_20.sort_values(by="Total Sales", ascending=False)
top_products_20
# Out:
# 0                          Total Sales
# Product
# Men's Street Footwear       37823020.0
# Women's Apparel             35190332.0
# Men's Athletic Footwear     31794462.0
# Women's Street Footwear     27426005.0
# Men's Apparel               26216964.0
# Women's Athletic Footwear   23629892.0

# %%
df_filled_21 = df[df['Year'] == 2021]
top_products_21 = df_filled[['Product','Total Sales']] . groupby('Product'). sum()
top_products_21 = top_products_21.sort_values(by="Total Sales", ascending=False)
top_products_21
# Out:
# 0                          Total Sales
# Product
# Men's Street Footwear       37823020.0
# Women's Apparel             35190332.0
# Men's Athletic Footwear     31794462.0
# Women's Street Footwear     27426005.0
# Men's Apparel               26216964.0
# Women's Athletic Footwear   23629892.0

# %%
top_products_20.plot(kind='bar',figsize=(12,7), title='TOTAL SALES PER PRODUCT IN 2020')
plt.show()

# %%
top_products_21.plot(kind='bar',figsize=(12,7), title='TOTAL SALES PER PRODUCTS IN 2021')
plt.show()

# %%
sales_region= df_filled[['Region', 'Total Sales']] . groupby ('Region').sum()
sales_region = sales_region.sort_values(by="Total Sales", ascending=False)
sales_region
# Out:
# 0          Total Sales
# Region
# West        76895153.0
# Northeast   40749709.0
# Southeast   31600863.0
# South       25456882.0
# Midwest      7378068.0

# %%
sales_region_21= df_filled_21[['Region', 'Total Sales']] . groupby ('Region').sum()
sales_region_21 = sales_region_21.sort_values(by="Total Sales", ascending=False)
sales_region_21
# Out:
# 0          Total Sales
# Region
# West       193048029.0
# Northeast  145574358.0
# Southeast  131570373.0
# Midwest    128422391.0
# South      119206299.0

# %%
sales_region.plot(kind='bar', figsize=(14,8), title='SALES PER REGION 2020')
plt.show()

# %%
sales_region_21.plot(kind='bar', figsize=(14,8), title='SALES PER REGION 2021')
plt.show()

# %%
top_retailers_20= df_filled[['Retailer','Total Sales']].groupby('Retailer').sum()

# %%
top_retailers_21= df_filled_21[['Retailer','Total Sales']].groupby('Retailer').sum()
top_retailers_21
# Out:
# 0              Total Sales
# Retailer
# Amazon          77698912.0
# Foot Locker    177217915.0
# Kohl's         101356250.0
# Sports Direct  167209896.0
# Walmart         41673410.0
# West Gear      152665067.0

# %%
top_retailers_20.plot(kind='bar',figsize=(12,7),title='Total sales per Retailer 2020')
# Out:
# <AxesSubplot:title={'center':'Total sales per Retailer 2020'}, xlabel='Retailer'>

# %%
top_retailers_21.plot(kind='bar',figsize=(12,7),title='Total sales per Retailer 2021')
# Out:
# <AxesSubplot:title={'center':'Total sales per Retailer 2021'}, xlabel='Retailer'>

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender
# ...

# %%
df.shape
# Out:
# (9648, 16)

# %%
df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method', 'Year', 'Month',
#        'Gender'],
#       dtype='object', name=0)

# %%
df['Retailer'].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['Northeast', 'South', 'West', 'Midwest', 'Southeast'], dtype=object)

# %%
sales_state = df_filled_21[['State','Total Sales']].groupby('State').sum()

# %%
sales_state = sales_state.sort_values(by="Total Sales", ascending=False)
sales_state
# Out:
# 0               Total Sales
# State
# California       51464743.0
# South Carolina   29285637.0
# Florida          27682851.0
# New York         24427804.0
# North Carolina   23956531.0
# Louisiana        23750781.0
# Hawaii           22282457.0
# Virginia         21575040.0
# Oregon           21349674.0
# Texas            20902864.0
# New Mexico       19865016.0
# Idaho            19276878.0
# Georgia          18997466.0
# Michigan         18625433.0
# Wyoming          18577517.0
# Ohio             18484583.0
# Tennessee        18067440.0
# Alabama          17633424.0
# New Hampshire    16411667.0
# Arizona          15782221.0
# Montana          15710886.0
# Mississippi      15591709.0
# Alaska           14753103.0
# Vermont          14352923.0
# Arkansas         12639347.0
# Delaware         12298412.0
# Connecticut      11573448.0
# Massachusetts    11076810.0
# West Virginia    10689160.0
# Oklahoma         10620734.0
# Kentucky         10072848.0
# Kansas            9972864.0
# ...

# %%
sales_state.plot(kind='bar',figsize=(12,7), title='Total Sales per state 2021')
plt.show()

# %%
sales_profits = df[['Sales Method','Operating Profit']].groupby('Sales Method').sum()

# %%
df['Price per Unit'].plot(kind='hist',bins=25,figsize=(12,7),title='Products price distribution')
# Out:
# <AxesSubplot:title={'center':'Products price distribution'}, ylabel='Frequency'>

# %%
top_salesmt= df_filled[['Sales Method','Total Sales']].groupby('Sales Method').sum()

# %%
top_salesmt= df_filled_21[['Sales Method','Total Sales']].groupby('Sales Method').sum()

# %%
top_salesmt.plot(kind='barh',title='Top Selling Methods 2020')
# Out:
# <AxesSubplot:title={'center':'Top Selling Methods 2020'}, ylabel='Sales Method'>

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender
# ...

# %%
df_filtered = df[df['Year'] == 2020]
df_southeast =  df_filtered.pivot_table(values='Total Sales', index='Month', columns='Region', fill_value=0)

# Define the order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Reindex the pivot table with the defined month order
df_southeast = df_southeast.reindex(month_order)

# Plotting the pivot table
df_southeast.plot.line()
plt.xticks(range(len(df_southeast.index)), df_southeast.index)
# Adding labels and title
plt.xlabel('Month,2020')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Month')
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
df_filtered = df[df['Year'] == 2020]
df_states = df_filtered.pivot_table(values='Total Sales', index=['Region','State'], columns='Month', fill_value=0)
region = 'West'

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

West_data = df_states.loc[region, months].round(2)
West_data.plot.bar()
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Sales at West Region')
plt.xticks(rotation=45)
West_data
# Out:
# Month         January   February      March      April        May       June  \
# State
# California       0.00       0.00       0.00       0.00  110345.00  135768.33
# Colorado    131210.00  180440.75   91504.93  198507.60  151596.42  106339.50
# Nevada       81930.48  114208.31   84792.62  110342.50   78617.33   98513.33
# Washington  259155.00  211650.83  204353.67  170544.67  158309.10  178649.17
#
# Month            July     August  September    October   November   December
# State
# California  115447.67  127131.33  127328.00  100653.33  134598.83  149823.73
# Colorado    142861.50  154485.50  143314.50  111808.50   88064.25   79080.50
# Nevada      106100.89  108594.11  111401.00  104918.00   85469.89   91764.78
# Washington  184789.11  197193.33  175074.83  164852.50  141982.25  144617.00

# %%
df_filtered = df[df['Year'] == 2021]
df_states = df_filtered.pivot_table(values='Total Sales', index=['Region','State'], columns='Month', fill_value=0)
region = 'West'

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

West_data = df_states.loc[region, months].round(2)
West_data.plot.bar()
plt.xlabel('State')
plt.ylabel('Total Sales')
plt.title('Sales at West Region')
plt.xticks(rotation=45)
West_data
# Out:
# Month         January   February     March      April        May       June  \
# State
# Alaska       84684.00   86157.25  75982.50   70836.50  110738.75  129675.50
# Arizona      63639.33   50377.17  52151.83   60910.22   70721.39   87355.44
# California  174134.84  134668.73  97149.71  126181.44  139572.35  158832.50
# Hawaii       93577.17  108468.33      0.00       0.00       0.00       0.00
# Idaho        49457.56   51709.89      0.00   99043.83   82613.17   95614.64
# New Mexico   52901.39   50868.22  67106.44   76894.50   87545.94  111203.89
# Oregon       53269.89   46725.39  50979.11   57168.67   68066.50  168210.56
# Utah         40482.61   48387.44      0.00       0.00       0.00       0.00
# Wyoming      59234.83   70877.17      0.00       0.00       0.00       0.00
#
# Month            July     August  September    October   November   December
# State
# Alaska      137833.92  122451.08   94852.92   81741.90  121700.92  182181.50
# ...

# %%
df['Retailer'].value_counts()
# Out:
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: Retailer, dtype: int64

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender
# ...

# %%
top_salesbasedongender= df[['Gender','Total Sales']].groupby('Gender').sum()

# %%
top_salesbasedongender.plot(kind='bar', title = 'TOP SALES BASED OF GENDER')
# Out:
# <AxesSubplot:title={'center':'TOP SALES BASED OF GENDER'}, xlabel='Gender'>

# %%
grouped_data = df.groupby(['Region','Gender'])['Total Sales'].sum().unstack()

# %%
ax = grouped_data.plot(kind='bar', figsize=(10, 6))
plt.title('Sales of Men\'s and Women\'s Footwear by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.legend(title='Product Type', labels=["Men's Footwear", "Women's Footwear"])

plt.show()

# %%
def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Fall'
    else:
        return 'Winter'

# %%
df['Invoice Date'] = pd.to_datetime(df['Invoice Date'])

# %%
df['Season'] = df['Invoice Date'].dt.month.apply(get_season)

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender  \
# ...

# %%
top_salesbasedonseason= df[['Season','Total Sales']].groupby('Season').sum()

# %%
top_salesbasedonseason.plot(kind='bar', title = 'TOP SALES BASED ON SEASON')
# Out:
# <AxesSubplot:title={'center':'TOP SALES BASED ON SEASON'}, xlabel='Season'>

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender  \
# ...

# %%
df['Sales Method'].nunique()
# Out:
# 3

# %%
df_filtered = df[df['Year'] == 2021]
df_southeast =  df_filtered.pivot_table(values='Total Sales', index='Month', columns='Region', fill_value=0)

# Define the order of months
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Reindex the pivot table with the defined month order
df_southeast = df_southeast.reindex(month_order)

# Plotting the pivot table
df_southeast.plot.line()
plt.xticks(range(len(df_southeast.index)), df_southeast.index)
# Adding labels and title
plt.xlabel('Month,2021')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Month')
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
IQR = 1.5 * (df['Total Sales'].quantile(0.75) - df['Total Sales'].quantile(0.25))

# Convert the float64 array to an integer array
df['Total Sales_int'] = df['Total Sales'].astype(int)

# Identify outliers
outliers = df[(df['Total Sales_int'] < (df['Total Sales'].quantile(0.25) - IQR)) | (df['Total Sales_int'] > (df['Total Sales'].quantile(0.75) + IQR))]

# %%
outliers
# Out:
# 0        Retailer Retailer ID Invoice Date     Region          State  \
# 1     Foot Locker     1185732   2020-01-01  Northeast       New York
# 2     Foot Locker     1185732   2020-02-01  Northeast       New York
# 3     Foot Locker     1185732   2020-03-01  Northeast       New York
# 4     Foot Locker     1185732   2020-04-01  Northeast       New York
# 5     Foot Locker     1185732   2020-05-01  Northeast       New York
# ...           ...         ...          ...        ...            ...
# 3832       Amazon     1185732   2021-05-17  Northeast  New Hampshire
# 3838       Amazon     1185732   2021-06-19  Northeast  New Hampshire
# 3844       Amazon     1185732   2021-07-17  Northeast  New Hampshire
# 3850       Amazon     1185732   2021-08-18  Northeast  New Hampshire
# 3874  Foot Locker     1185732   2021-12-17  Northeast  New Hampshire
#
# 0           City                    Product  Price per Unit  Units Sold  \
# ...

# %%
plt.figure(figsize = (10,5))
df.boxplot()
plt.title('boxplots for dataframe columns')
plt.ylabel('values')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 1 to 9648
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   float64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
#  13  Year              9648 non-null   int64
#  14  Month             9648 non-null   object
#  15  Gender            9648 non-null   object
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
# 0     Retailer Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-02-01  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-03-01  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-04-01  Northeast  New York  New York
# 5  Foot Locker     1185732   2020-05-01  Northeast  New York  New York
#
# 0                    Product  Price per Unit  Units Sold  Total Sales  \
# 1      Men's Street Footwear            50.0      1200.0     600000.0
# 2    Men's Athletic Footwear            50.0      1000.0     500000.0
# 3    Women's Street Footwear            40.0      1000.0     400000.0
# 4  Women's Athletic Footwear            45.0       850.0     382500.0
# 5              Men's Apparel            60.0       900.0     540000.0
#
# 0 Operating Profit  Operating Margin Sales Method  Year     Month  Gender  \
# ...

# %%
df2['Region']=pd.factorize(df2.Region)[0]
df2['State']=pd.factorize(df2.State)[0]
df2['City']=pd.factorize(df2.City)[0]
df2['Product']=pd.factorize(df2.Product)[0]
df2['Retailer']=pd.factorize(df2.Retailer)[0]
df2['Year']=pd.factorize(df2.Year)[0]
df2['Month']=pd.factorize(df2.Month)[0]
df2['Gender']=pd.factorize(df2.Gender)[0]
df2['Season']=pd.factorize(df2.Season)[0]
df2.rename(columns = {'Sales Method':'Method'}, inplace = True)
df2['Method']=pd.factorize(df2.Method)[0]
df2 = df2.drop('Invoice Date',axis=1)

# %%
df2.head()
# Out:
# 0  Retailer Retailer ID  Region  State  City  Product  Price per Unit  \
# 1         0     1185732       0      0     0        0            50.0
# 2         0     1185732       0      0     0        1            50.0
# 3         0     1185732       0      0     0        2            40.0
# 4         0     1185732       0      0     0        3            45.0
# 5         0     1185732       0      0     0        4            60.0
#
# 0  Units Sold  Total Sales Operating Profit  Operating Margin  Method  Year  \
# 1      1200.0     600000.0           300000              50.0       0     0
# 2      1000.0     500000.0           150000              30.0       0     0
# 3      1000.0     400000.0           140000              35.0       0     0
# 4       850.0     382500.0           133875              35.0       0     0
# 5       900.0     540000.0           162000              30.0       0     0
#
# 0  Month  Gender  Season  Total Sales_int
# 1      0       0       0           600000
# ...

# %%
df2 = df2.drop('Retailer ID',axis=1)

# %%
df2.head()
# Out:
# 0  Retailer  Region  State  City  Product  Price per Unit  Units Sold  \
# 1         0       0      0     0        0            50.0      1200.0
# 2         0       0      0     0        1            50.0      1000.0
# 3         0       0      0     0        2            40.0      1000.0
# 4         0       0      0     0        3            45.0       850.0
# 5         0       0      0     0        4            60.0       900.0
#
# 0  Total Sales Operating Profit  Operating Margin  Method  Year  Month  \
# 1     600000.0           300000              50.0       0     0      0
# 2     500000.0           150000              30.0       0     0      1
# 3     400000.0           140000              35.0       0     0      2
# 4     382500.0           133875              35.0       0     0      3
# 5     540000.0           162000              30.0       0     0      4
#
# 0  Gender  Season  Total Sales_int
# 1       0       0           600000
# 2       0       0           500000
# ...

# %%
df2 = df2.drop('Total Sales_int',axis=1)

# %%
df2['Units Sold'] = df2['Units Sold'].astype(int)
df2['Total Sales'] = df2['Total Sales'].astype(int)
df2['Operating Profit'] = df2['Operating Profit'].astype(int)
df2['Retailer'] = df2['Retailer'].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 1 to 9648
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   int32
#  1   Region            9648 non-null   int64
#  2   State             9648 non-null   int64
#  3   City              9648 non-null   int64
#  4   Product           9648 non-null   int64
#  5   Price per Unit    9648 non-null   float64
#  6   Units Sold        9648 non-null   int32
#  7   Total Sales       9648 non-null   int32
#  8   Operating Profit  9648 non-null   int32
#  9   Operating Margin  9648 non-null   float64
#  10  Method            9648 non-null   int64
#  11  Year              9648 non-null   int64
#  12  Month             9648 non-null   int64
#  13  Gender            9648 non-null   int64
#  14  Season            9648 non-null   int64
# dtypes: float64(2), int32(4), int64(9)
# memory usage: 980.0 KB

# %%
df2.corr()
# Out:
# 0                 Retailer    Region     State      City   Product  \
# 0
# Retailer          1.000000 -0.097952  0.096816  0.096194  0.002262
# Region           -0.097952  1.000000 -0.209003 -0.176060 -0.000121
# State             0.096816 -0.209003  1.000000  0.976045  0.000367
# City              0.096194 -0.176060  0.976045  1.000000  0.000393
# Product           0.002262 -0.000121  0.000367  0.000393  1.000000
# Price per Unit    0.057918  0.042493 -0.147839 -0.143264  0.190119
# Units Sold        0.007130  0.095324 -0.251792 -0.244089 -0.177418
# Total Sales       0.016339  0.079305 -0.158281 -0.151011 -0.055137
# Operating Profit  0.012788  0.072539 -0.145209 -0.137264 -0.054475
# Operating Margin  0.001682 -0.002096 -0.019765 -0.023920  0.010860
# Method           -0.005612  0.130336 -0.013363 -0.011398 -0.000524
# Year              0.078588 -0.010242  0.471849  0.508534 -0.000288
# Month             0.014708 -0.004452  0.026262  0.047586  0.003721
# ...

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:xlabel='0', ylabel='0'>

# %%
X = df2.values[:, (0,1,2,3,4,5,6,8,9,10,11,12,13,14)]
Y = df2.values[:, 7]

# %%
Y
# Out:
# array([600000., 500000., 400000., ...,   7544.,   2940.,   2407.])

# %%
X.shape
# Out:
# (9648, 14)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.9587591854762874

# %%
from sklearn.metrics import classification_report

# %%
y_pred
# Out:
# array([-38020.22813092,   9698.24037609,  29674.93823689, ...,
#        -14806.29977958,  33506.76243929, 117127.13268672])

# %%
y_test
# Out:
# array([  4352.,   7956.,   3900., ...,   3965.,  10692., 105000.])

# %%
y_pred = y_pred.argmax(axis=0)

# %%
classification_report(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 96 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#Y164sdW50aXRsZWQ%3D?line=0'>1</a> classification_report(y_test,y_pred)
#
# File c:\Users\Rich\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:2110, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1998 def classification_report(
#    1999     y_true,
#    2000     y_pred,
#    (...)
#    2007     zero_division="warn",
#    2008 ):
#    2009     """Build a text report showing the main classification metrics.
#    2010
#    2011     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2107     <BLANKLINE>
#    2108     """
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...

# %%
# Out:
# 161
